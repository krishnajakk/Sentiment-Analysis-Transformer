# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
# Reading data
df = pd.read_csv('/content/drive/MyDrive/Datasets/Reviews.csv')

# %%
print(df.shape)
df = df.head(500)
print(df.shape)
df
# Out:
# (568454, 10)
# (500, 10)
#       Id   ProductId          UserId                      ProfileName  \
# 0      1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1      2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2      3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3      4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4      5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ..   ...         ...             ...                              ...
# 495  496  B000G6RYNE   APGAA43E3WPN7                           Darren
# 496  497  B000G6RYNE    ABR7HU5H1KNE                            Keith
# 497  498  B000G6RYNE   AJQD2WWJYOYFQ                          bubbles
# 498  499  B000G6RYNE  A16YH487W9ZYO0                 Bruce G. Lindsay
# 499  500  B000G6RYNE   A83YQC1XOU4CS                         J. Baker
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %% [markdown]
# **Exploratory Data Analysis (EDA)**

# %%
score_values = df['Score'].value_counts().sort_index()
print(score_values)
# Out:
# 1     36
# 2     18
# 3     37
# 4     70
# 5    339
# Name: Score, dtype: int64

# %%
ax = score_values.plot(kind='bar',
             title='Review Count by Stars',
             figsize=(6,3),
             color='green')
ax.set_xlabel('Review stars')
plt.show()

# %% [markdown]
# **NLTK**

# %%
review = df['Text'][50]
print(review)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
nltk.word_tokenize(review)
# Out:
# ['This',
#  'oatmeal',
#  'is',
#  'not',
#  'good',
#  '.',
#  'Its',
#  'mushy',
#  ',',
#  'soft',
#  ',',
#  'I',
#  'do',
#  "n't",
#  'like',
#  'it',
#  '.',
#  'Quaker',
#  'Oats',
#  'is',
#  'the',
#  'way',
#  'to',
#  'go',
#  '.']

# %%
tokens = nltk.word_tokenize(review)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
pos = nltk.pos_tag(tokens)
pos[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(pos)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# **Vader - Sentiment Analysis**

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

# %%
sia_obj = SentimentIntensityAnalyzer()
sia_obj.polarity_scores('Im so excited to go for party.')
# Out:
# {'neg': 0.0, 'neu': 0.481, 'pos': 0.519, 'compound': 0.659}

# %%
sia_obj.polarity_scores('This is the worst thing happened ever')
# Out:
# {'neg': 0.406, 'neu': 0.594, 'pos': 0.0, 'compound': -0.6249}

# %%
sia_obj.polarity_scores(review)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
  text = row['Text']
  myid = row['Id']
  res[myid] = sia_obj.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index':'Id'})
vaders = vaders.merge(df, how='left')
vaders.head(2)
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId ProfileName  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW  delmartian
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK      dll pa
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...

# %%
fig, axs = plt.subplots(1, 3, figsize=(12,3))
sns.barplot(data=vaders, x='Score', y='pos', ax = axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax = axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax = axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Transformer - Sentiment Analysis**

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
def roberta_polarity_scores(rev):
  encoded_text = tokenizer(rev, return_tensors = 'pt')
  output = model(**encoded_text)
  scores = output[0][0].detach().numpy()
  scores = softmax(scores)
  scores_dict = {
      'roberta_neg' : scores[0],
      'roberta_neu' : scores[1],
      'roberta_pos' : scores[2]
  }
  return scores_dict

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
  try:
    text = row['Text']
    myid = row['Id']
    vader_score = sia_obj.polarity_scores(text)
    vader_score_renamed = {}
    for key, value in vader_score.items():
      vader_score_renamed[f"vader_{key}"] = value
    roberta_score = roberta_polarity_scores(text)
    both = {**vader_score_renamed, **roberta_score}
    res[myid] = both
  except RuntimeError:
    print(f"Broke for id {myid}")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187

# %%
final_df = pd.DataFrame(res).T
final_df = final_df.reset_index().rename(columns={'index':'Id'})
final_df = final_df.merge(df, how='left')
final_df.head(2)
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0   1      0.000      0.695      0.305          0.9441     0.009624
# 1   2      0.138      0.862      0.000         -0.5664     0.508986
#
#    roberta_neu  roberta_pos   ProductId          UserId ProfileName  \
# 0     0.049980     0.940395  B001E4KFG0  A3SGXH7AUHU8GW  delmartian
# 1     0.452414     0.038600  B00813GRG4  A1D87F6ZCVE5NK      dll pa
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...

# %% [markdown]
# **Comparison of the Models**

# %%
final_df.columns
# Out:
# Index(['Id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
sns.pairplot(data = final_df,
             vars = ['vader_neg', 'vader_neu', 'vader_pos',
                    'roberta_neg', 'roberta_neu', 'roberta_pos'],
             hue = 'Score',
             palette = 'tab20')
plt.show()

# %% [markdown]
# **Prediction Examples**

# %%
final_df.query('Score == 1').sort_values('roberta_pos', ascending = False)['Text'].values[0]
# Out:
# 'I felt energized within five minutes, but it lasted for about 45 minutes. I paid $3.99 for this drink. I could have just drunk a cup of coffee and saved my money.'

# %%
final_df.query('Score == 5').sort_values('roberta_pos', ascending = False)['Text'].values[0]
# Out:
# "These are my favorite bars ever. The combo of raisons and dark choc is wonderful! Very filling! These are hard to find in the stores. I'm thankful for subsrcibe and save!"

# %%
final_df.query('Score == 1').sort_values('vader_pos', ascending = False)['Text'].values[0]
# Out:
# 'So we cancelled the order.  It was cancelled without any problem.  That is a positive note...'
